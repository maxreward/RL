# %%
import gym
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Configuration parameters for the whole setup
seed = 42
gamma = 0.99  # Discount factor for past rewards
max_steps_per_episode = 10000
env = gym.make("CartPole-v0")  # Create the environment
env.seed(seed)
eps = np.finfo(np.float32).eps.item()  # Smallest number such that 1.0 + eps != 1.0

# %%
num_inputs = 4
num_actions = 2
num_hidden = 128

inputs = layers.Input(shape=(num_inputs,))
common = layers.Dense(num_hidden, activation="relu")(inputs)
action = layers.Dense(num_actions, activation="softmax")(common)
critic = layers.Dense(1)(common)

model = keras.Model(inputs=inputs, outputs=[action, critic])

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.01)
huber_loss = keras.losses.Huber()
action_probs_history = []
critic_value_history = []
rewards_history = []
running_reward = 0
episode_count = 0

while True:  # Run until solved
    state = env.reset()
    episode_reward = 0
    with tf.GradientTape() as tape:
        for timestep in range(1, max_steps_per_episode):
            # env.render(); Adding this line would show the attempts
            # of the agent in a pop up window.

            state = tf.convert_to_tensor(state)
            state = tf.expand_dims(state, 0)

            # Predict action probabilities and estimated future rewards
            # from environment state
            action_probs, critic_value = model(state)
            critic_value_history.append(critic_value[0, 0])

            # Sample action from action probability distribution
            action = np.random.choice(num_actions, p=np.squeeze(action_probs))
            action_probs_history.append(tf.math.log(action_probs[0, action]))

            # Apply the sampled action in our environment
            state, reward, done, _ = env.step(action)
            rewards_history.append(reward)
            episode_reward += reward

            if done:
                break

        # Update running reward to check condition for solving
        running_reward = 0.05 * episode_reward + (1 - 0.05) * running_reward

        # Calculate expected value from rewards
        # - At each timestep what was the total reward received after that timestep
        # - Rewards in the past are discounted by multiplying them with gamma
        # - These are the labels for our critic
        returns = []
        discounted_sum = 0
        for r in rewards_history[::-1]:
            discounted_sum = r + gamma * discounted_sum
            returns.insert(0, discounted_sum)

        # Normalize
        returns = np.array(returns)
        returns = (returns - np.mean(returns)) / (np.std(returns) + eps)
        returns = returns.tolist()

        # Calculating loss values to update our network
        history = zip(action_probs_history, critic_value_history, returns)
        actor_losses = []
        critic_losses = []
        for log_prob, value, ret in history:
            # At this point in history, the critic estimated that we would get a
            # total reward = `value` in the future. We took an action with log probability
            # of `log_prob` and ended up recieving a total reward = `ret`.
            # The actor must be updated so that it predicts an action that leads to
            # high rewards (compared to critic's estimate) with high probability.
            diff = ret - value
            actor_losses.append(-log_prob * diff)  # actor loss

            # The critic must be updated so that it predicts a better estimate of
            # the future rewards.
            critic_losses.append(
                huber_loss(tf.expand_dims(value, 0), tf.expand_dims(ret, 0))
            )

        # Backpropagation
        loss_value = sum(actor_losses) + sum(critic_losses)
        grads = tape.gradient(loss_value, model.trainable_variables)
        optimizer.apply_gradients(zip(grads, model.trainable_variables))

        # Clear the loss and reward history
        action_probs_history.clear()
        critic_value_history.clear()
        rewards_history.clear()

    # Log details
    episode_count += 1
    if episode_count % 10 == 0:
        template = "running reward: {:.2f} at episode {}"
        print(template.format(running_reward, episode_count))

    if running_reward > 195:  # Condition to consider the task solved
        print("Solved at episode {}!".format(episode_count))
        break
# Out:
# running reward: 5.90 at episode 10
# running reward: 9.04 at episode 20
# running reward: 11.77 at episode 30
# running reward: 14.82 at episode 40
# running reward: 14.36 at episode 50
# running reward: 13.86 at episode 60
# running reward: 16.34 at episode 70
# running reward: 19.00 at episode 80
# running reward: 26.05 at episode 90
# running reward: 31.54 at episode 100
# running reward: 32.33 at episode 110
# running reward: 29.91 at episode 120
# running reward: 25.78 at episode 130
# running reward: 24.71 at episode 140
# running reward: 33.07 at episode 150
# running reward: 31.35 at episode 160
# running reward: 42.21 at episode 170
# running reward: 53.00 at episode 180
# running reward: 56.99 at episode 190
# running reward: 61.70 at episode 200
# running reward: 58.74 at episode 210
# running reward: 55.89 at episode 220
# running reward: 58.51 at episode 230
# running reward: 61.02 at episode 240
# running reward: 63.79 at episode 250
# running reward: 79.12 at episode 260
# running reward: 93.83 at episode 270
# running reward: 89.32 at episode 280
# running reward: 84.62 at episode 290
# running reward: 101.65 at episode 300
# running reward: 130.15 at episode 310
# running reward: 156.37 at episode 320
# running reward: 173.88 at episode 330
# running reward: 165.85 at episode 340
# running reward: 121.82 at episode 350
# running reward: 98.00 at episode 360
# running reward: 96.26 at episode 370
# running reward: 110.52 at episode 380
# running reward: 142.57 at episode 390
# running reward: 160.25 at episode 400
# running reward: 159.87 at episode 410
# running reward: 108.63 at episode 420
# running reward: 68.94 at episode 430
# running reward: 45.18 at episode 440
# running reward: 30.96 at episode 450
# running reward: 22.34 at episode 460
# running reward: 17.28 at episode 470
# running reward: 14.22 at episode 480
# running reward: 12.54 at episode 490
# running reward: 11.37 at episode 500
# running reward: 10.80 at episode 510
# running reward: 10.35 at episode 520
# running reward: 10.09 at episode 530
# running reward: 9.98 at episode 540
# running reward: 10.04 at episode 550
# running reward: 9.90 at episode 560
# running reward: 9.75 at episode 570
# running reward: 9.53 at episode 580
# running reward: 9.27 at episode 590
# running reward: 9.38 at episode 600
# running reward: 9.47 at episode 610
# running reward: 9.50 at episode 620
# running reward: 9.28 at episode 630
# running reward: 9.37 at episode 640
# running reward: 9.61 at episode 650
# running reward: 9.61 at episode 660
# running reward: 9.57 at episode 670
# running reward: 9.52 at episode 680
# running reward: 9.61 at episode 690
# running reward: 9.64 at episode 700
# running reward: 9.49 at episode 710
# running reward: 9.53 at episode 720
# running reward: 9.30 at episode 730
# running reward: 9.26 at episode 740
# running reward: 9.33 at episode 750
# running reward: 9.28 at episode 760
# running reward: 9.38 at episode 770
# running reward: 9.19 at episode 780
# running reward: 9.59 at episode 790
# running reward: 9.53 at episode 800
# running reward: 9.59 at episode 810
# running reward: 9.46 at episode 820
# running reward: 9.45 at episode 830
# running reward: 9.58 at episode 840
# running reward: 9.33 at episode 850
# running reward: 9.34 at episode 860
# running reward: 9.54 at episode 870
# running reward: 9.78 at episode 880
# running reward: 9.63 at episode 890
# running reward: 9.59 at episode 900
# running reward: 9.66 at episode 910
# running reward: 9.57 at episode 920
# running reward: 9.58 at episode 930
# running reward: 9.58 at episode 940
# running reward: 9.54 at episode 950
# running reward: 9.53 at episode 960
# running reward: 9.32 at episode 970
# running reward: 9.35 at episode 980
# running reward: 9.49 at episode 990
# running reward: 9.54 at episode 1000
# running reward: 9.60 at episode 1010
# running reward: 9.47 at episode 1020
# running reward: 9.58 at episode 1030
# running reward: 9.83 at episode 1040
# running reward: 9.83 at episode 1050
# running reward: 9.58 at episode 1060
# running reward: 9.88 at episode 1070
# running reward: 9.90 at episode 1080
# running reward: 10.26 at episode 1090
# running reward: 10.33 at episode 1100
# running reward: 10.27 at episode 1110
# running reward: 10.33 at episode 1120
# running reward: 10.46 at episode 1130
# running reward: 10.38 at episode 1140
# running reward: 10.34 at episode 1150
# running reward: 10.26 at episode 1160
# running reward: 10.31 at episode 1170
# running reward: 10.36 at episode 1180
# running reward: 10.37 at episode 1190
# running reward: 10.90 at episode 1200
# running reward: 11.56 at episode 1210
# running reward: 12.93 at episode 1220
# running reward: 12.30 at episode 1230
# running reward: 12.54 at episode 1240
# running reward: 66.05 at episode 1250
# running reward: 114.47 at episode 1260
# running reward: 148.79 at episode 1270
# running reward: 169.34 at episode 1280
# running reward: 176.13 at episode 1290
# running reward: 183.05 at episode 1300
# running reward: 178.34 at episode 1310
# running reward: 160.60 at episode 1320
# running reward: 172.72 at episode 1330
# running reward: 183.67 at episode 1340
# running reward: 182.31 at episode 1350
# running reward: 189.41 at episode 1360
# running reward: 182.91 at episode 1370
# running reward: 189.77 at episode 1380
# running reward: 142.19 at episode 1390
# running reward: 131.11 at episode 1400
# running reward: 120.59 at episode 1410
# running reward: 93.13 at episode 1420
# running reward: 95.18 at episode 1430
# running reward: 97.64 at episode 1440
# running reward: 108.35 at episode 1450
# running reward: 125.39 at episode 1460
# running reward: 147.41 at episode 1470
# running reward: 168.51 at episode 1480
# running reward: 181.15 at episode 1490
